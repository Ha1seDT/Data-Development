# %%
import pandas
df = pandas.read_csv("airports.csv")
df.head(10)
# Out:
#        id ident           type                                name  \
# 0    6523   00A       heliport                   Total RF Heliport
# 1  323361  00AA  small_airport                Aero B Ranch Airport
# 2    6524  00AK  small_airport                        Lowell Field
# 3    6525  00AL  small_airport                        Epps Airpark
# 4  506791  00AN  small_airport                Katmai Lodge Airport
# 5    6526  00AR         closed  Newport Hospital & Clinic Heliport
# 6  322127  00AS  small_airport                      Fulton Airport
# 7    6527  00AZ  small_airport                      Cordes Airport
# 8    6528  00CA  small_airport             Goldstone (GTS) Airport
# 9  324424  00CL  small_airport                 Williams Ag Airport
#
#    latitude_deg  longitude_deg  elevation_ft continent iso_country iso_region  \
# 0     40.070985     -74.933689          11.0       NaN          US      US-PA
# ...

# %%
df.drop( ["latitude_deg","longitude_deg","elevation_ft","continent","home_link","wikipedia_link","keywords"], axis='columns', inplace=True)

# %%
df.head(10)
# Out:
#        id ident           type                                name  \
# 0    6523   00A       heliport                   Total RF Heliport
# 1  323361  00AA  small_airport                Aero B Ranch Airport
# 2    6524  00AK  small_airport                        Lowell Field
# 3    6525  00AL  small_airport                        Epps Airpark
# 4  506791  00AN  small_airport                Katmai Lodge Airport
# 5    6526  00AR         closed  Newport Hospital & Clinic Heliport
# 6  322127  00AS  small_airport                      Fulton Airport
# 7    6527  00AZ  small_airport                      Cordes Airport
# 8    6528  00CA  small_airport             Goldstone (GTS) Airport
# 9  324424  00CL  small_airport                 Williams Ag Airport
#
#   iso_country iso_region  municipality scheduled_service gps_code iata_code  \
# 0          US      US-PA      Bensalem                no     K00A       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82077 entries, 0 to 82076
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 82077 non-null  int64
#  1   ident              82077 non-null  object
#  2   type               82077 non-null  object
#  3   name               82077 non-null  object
#  4   iso_country        81817 non-null  object
#  5   iso_region         82077 non-null  object
#  6   municipality       77267 non-null  object
#  7   scheduled_service  82077 non-null  object
#  8   gps_code           43056 non-null  object
#  9   iata_code          9103 non-null   object
#  10  local_code         34606 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 6.9+ MB

# %%
non_numerical_columns = df.select_dtypes(exclude=['number']).columns
df[non_numerical_columns] = df[non_numerical_columns].fillna('Missing Value')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82077 entries, 0 to 82076
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 82077 non-null  int64
#  1   ident              82077 non-null  object
#  2   type               82077 non-null  object
#  3   name               82077 non-null  object
#  4   iso_country        82077 non-null  object
#  5   iso_region         82077 non-null  object
#  6   municipality       82077 non-null  object
#  7   scheduled_service  82077 non-null  object
#  8   gps_code           82077 non-null  object
#  9   iata_code          82077 non-null  object
#  10  local_code         82077 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 6.9+ MB
